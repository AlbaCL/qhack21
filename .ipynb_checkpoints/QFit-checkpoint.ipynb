# %%
import tequila as tq
import numpy as np
import matplotlib.pyplot as plt
from numpy import random
import time
from sklearn import preprocessing

# %%
def qcircuit(xval, param):
    """
    Arg:
        - xval (array[tuple]): data point
        - param (dict): parameters dictionary
    Returns:
        - qc: quantum circuit
    """
    layers = int((len(param))/3) # 2 parameters/layer
    # initialize the circuit 
    qc = tq.gates.Rz(0.0,0)
    for p in range(0,3*layers-1,3):
        # add layers to the circuit
        qc += tq.gates.Ry(param[p],0) + tq.gates.Rz(xval*param[p+1]+param[p+2],0) 
        #tq.gates.Ry(xval*param[p]+param[p+1],0) + tq.gates.Rz(xval*param[p+2]+param[p+3],0) 
    return qc

# %%
# Function
def f(x):
    func = 3*x**3*(1-x**4)
    return func

# %%
# Optimize
training_set = 50
layers = 4

# generate the training data
xdata=[]
for i in range(training_set):
    rand = random.uniform(-1,1)
    xdata.append(rand)
    
# generate the variational parameters
param = [tq.Variable(name='th_{}'.format(i)) for i in range(0,3*layers)]

# initialize the variational parameters
# note that due to the random initialization the result can be different from time to time
# With gradient based optimization you might get stuck
inval = {key : random.uniform(0, 2*np.pi) for key in param}

grad = '2-point' # numerical gradient (= None: analytical gradient)
mthd = 'BFGS' # scipy minimization method
mthd_opt = {'eps':1.e-4} # method options (that's the stepsize for the gradients)

#print(xdata)
loss=0
for i in range(training_set):
    wfn_targ = tq.QubitWaveFunction.from_array(np.asarray([np.sqrt(abs((1+f(xdata[i]))/2)),np.sqrt(abs((1-f(xdata[i]))/2))]))
    wfn = wfn_targ.normalize()
    rho_targ =  tq.paulis.Projector(wfn=wfn)
    obj = tq.Objective.ExpectationValue(U=qcircuit(xdata[i], param), H=rho_targ)
    loss += (obj-f(xdata[i]))**2
test = tq.minimize(objective=loss/len(xdata), initial_values=inval, method = mthd, gradient = grad, method_options = mthd_opt, silent=False)
# Out:
# Optimizer: <class 'tequila.optimizers.optimizer_scipy.OptimizerSciPy'>
# backend         : qulacs
# device          : None
# samples         : None
# save_history    : True
# noise           : None
#
# Method          : BFGS
# Objective       : 50 expectationvalues
# grad instr      : 2-point
# gradient        : scipy numerical 2-point
# hessian         : scipy numerical None
#
# active variables : 12
#
# E=+0.20802839  angles= {th_0: 0.8338041263924659, th_1: 5.6041478740937505, th_2: 2.4695538862674495, th_3: 2.17469947784999, th_4: 3.376791694418299, th_5: 5.866772325193705, th_6: 5.957205858502685, th_7: 1.9156282917628646, th_8: 5.081086181905332, th_9: 1.521454034513123, th_10: 5.461530376370003, th_11: 3.786617254447167}  samples= None
# ...

# %%
print("loss = ", test.energy)
print("method: ", mthd)
print("method parameters: ", mthd_opt)

print(test.history.plot('energies', label='loss'))
#print(test.history.plot('angles', label=""))
# Out:
# loss =  0.0005283072977447833
# method:  BFGS
# method parameters:  {'eps': 0.0001, 'maxiter': 100, 'disp': True}
# None

# %%
zero=tq.QubitWaveFunction.from_array(np.asarray([1,0]))
zero=zero.normalize()
ytrain=[]
ytrue=[]
for i in range(training_set):
    qc=qcircuit(xdata[i],param)
    train_wfn = tq.simulate(qc,variables=test.angles)
    fid = abs(train_wfn.inner(zero))**2
    ytrain.append(fid)
    ytrue.append(f(xdata[i]))

# %%
plt.plot(xdata, ytrain, 'o', color='black');
plt.plot(xdata, ytrue, 'o', color='red');

# %%
# Function
def f(x):
    #func = 3*x**3*(1-x**4)
    func = np.sin(10*x)/(10*x)
    return func

# %%
# Optimize
training_set = 50
layersmax = 6

# generate the training data
xdata=[]
ytrue=[]
for i in range(training_set):
    rand = random.uniform(-1,1)
    xdata.append(rand)
    ytrue.append(f(rand))    

plt.plot(xdata, ytrue, 'o', color='black')
    
zero=tq.QubitWaveFunction.from_array(np.asarray([1,0]))
zero=zero.normalize()
    
grad = '2-point' # numerical gradient (= None: analytical gradient)
mthd = 'BFGS' # scipy minimization method
mthd_opt = {'eps':1.e-4} # method options (that's the stepsize for the gradients)

col = ['red','blue','yellow','green','pink','brown']
 
for k in range(layersmax):
    layers = k+1
    # generate the variational parameters
    param = [tq.Variable(name='th_{}'.format(i)) for i in range(0,3*layers)]
    inval = {key : random.uniform(0, 2*np.pi) for key in param}

    #print(xdata)
    loss=0
    for i in range(training_set):
        wfn_targ = tq.QubitWaveFunction.from_array(np.asarray([np.sqrt((1+f(xdata[i]))/2),np.sqrt((1-f(xdata[i]))/2)]))
        wfn = wfn_targ.normalize()
        rho_targ =  tq.paulis.Projector(wfn=wfn)
        obj = tq.Objective.ExpectationValue(U=qcircuit(xdata[i], param), H=rho_targ)
        loss += (obj-f(xdata[i]))**2
    test = tq.minimize(objective=loss/len(xdata), initial_values=inval, method = mthd, gradient = grad, method_options = mthd_opt, silent=True)
    ytrain=[]
    for i in range(training_set):
        qc=qcircuit(xdata[i],param)
        #train_wfn = tq.simulate(qc,variables=test.angles)
        #fid = abs(train_wfn.inner(zero))**2
        #ytrain.append(fid)
        train_exp = tq.ExpectationValue(qc,H=tq.paulis.Z(0))
        ytrain.append(tq.simulate(train_exp,variables=test.angles))

    plt.plot(xdata, ytrain, 'o', color=col[k])
plt.show()

# %%
def qcircuit(xval, param):
    """
    Arg:
        - xval (array[tuple]): data point
        - param (dict): parameters dictionary
    Returns:
        - qc: quantum circuit
    """
    layers = int((len(param))/3) # 2 parameters/layer
    # initialize the circuit 
    qc = tq.gates.Rz(0.0,0)
    for p in range(0,3*layers-1,3):
        # add layers to the circuit
        qc += tq.gates.Rz(param[p],0) + tq.gates.Ry(xval*param[p+1]+param[p+2],0) 
        #tq.gates.Ry(xval*param[p]+param[p+1],0) + tq.gates.Rz(xval*param[p+2]+param[p+3],0) 
    return qc

# %%
# Optimize
training_set = 50
layersmax = 6

# generate the training data
xdata=[]
ytrue=[]
for i in range(training_set):
    rand = random.uniform(-1,1)
    xdata.append(rand)
    ytrue.append(f(rand))    

plt.plot(xdata, ytrue, 'o', color='black')
    
zero=tq.QubitWaveFunction.from_array(np.asarray([1,0]))
zero=zero.normalize()
    
grad = '2-point' # numerical gradient (= None: analytical gradient)
mthd = 'BFGS' # scipy minimization method
mthd_opt = {'eps':1.e-4} # method options (that's the stepsize for the gradients)

col = ['red','blue','yellow','green','pink','brown']
 
for k in range(layersmax):
    layers = k+1
    # generate the variational parameters
    param = [tq.Variable(name='th_{}'.format(i)) for i in range(0,3*layers)]
    inval = {key : random.uniform(0, 2*np.pi) for key in param}

    #print(xdata)
    loss=0
    for i in range(training_set):
        wfn_targ = tq.QubitWaveFunction.from_array(np.asarray([np.sqrt((1+f(xdata[i]))/2),np.sqrt((1-f(xdata[i]))/2)]))
        wfn = wfn_targ.normalize()
        rho_targ =  tq.paulis.Projector(wfn=wfn)
        obj = tq.Objective.ExpectationValue(U=qcircuit(xdata[i], param), H=rho_targ)
        loss += (obj-f(xdata[i]))**2
    test = tq.minimize(objective=loss/len(xdata), initial_values=inval, method = mthd, gradient = grad, method_options = mthd_opt, silent=True)
    ytrain=[]
    for i in range(training_set):
        qc=qcircuit(xdata[i],param)
        #train_wfn = tq.simulate(qc,variables=test.angles)
        #fid = abs(train_wfn.inner(zero))**2
        #ytrain.append(fid)
        train_exp = tq.ExpectationValue(qc,H=tq.paulis.Z(0))
        ytrain.append(tq.simulate(train_exp,variables=test.angles))

    plt.plot(xdata, ytrain, 'o', color=col[k])
plt.show()

# %%
def qcircuit(xval, param):
    """
    Arg:
        - xval (array[tuple]): data point
        - param (dict): parameters dictionary
    Returns:
        - qc: quantum circuit
    """
    layers = int((len(param))/3) # 2 parameters/layer
    # initialize the circuit 
    qc = tq.gates.Rz(0.0,0)
    for p in range(0,3*layers-1,3):
        # add layers to the circuit
        qc += tq.gates.Rz(param[p],0) + tq.gates.Ry(xval*param[p+1]+param[p+2],0) +tq.gates.Rz(xval,0)
        #tq.gates.Ry(xval*param[p]+param[p+1],0) + tq.gates.Rz(xval*param[p+2]+param[p+3],0) 
    return qc

# %%
# Optimize
training_set = 50
layersmax = 6

# generate the training data
xdata=[]
ytrue=[]
for i in range(training_set):
    rand = random.uniform(-1,1)
    xdata.append(rand)
    ytrue.append(f(rand))    

plt.plot(xdata, ytrue, 'o', color='black')
    
zero=tq.QubitWaveFunction.from_array(np.asarray([1,0]))
zero=zero.normalize()
    
grad = '2-point' # numerical gradient (= None: analytical gradient)
mthd = 'BFGS' # scipy minimization method
mthd_opt = {'eps':1.e-4} # method options (that's the stepsize for the gradients)

col = ['red','blue','yellow','green','pink','brown']
 
for k in range(layersmax):
    layers = k+1
    # generate the variational parameters
    param = [tq.Variable(name='th_{}'.format(i)) for i in range(0,3*layers)]
    inval = {key : random.uniform(0, 2*np.pi) for key in param}

    #print(xdata)
    loss=0
    for i in range(training_set):
        wfn_targ = tq.QubitWaveFunction.from_array(np.asarray([np.sqrt((1+f(xdata[i]))/2),np.sqrt((1-f(xdata[i]))/2)]))
        wfn = wfn_targ.normalize()
        rho_targ =  tq.paulis.Projector(wfn=wfn)
        obj = tq.Objective.ExpectationValue(U=qcircuit(xdata[i], param), H=rho_targ)
        loss += (obj-f(xdata[i]))**2
    test = tq.minimize(objective=loss/len(xdata), initial_values=inval, method = mthd, gradient = grad, method_options = mthd_opt, silent=True)
    ytrain=[]
    for i in range(training_set):
        qc=qcircuit(xdata[i],param)
        #train_wfn = tq.simulate(qc,variables=test.angles)
        #fid = abs(train_wfn.inner(zero))**2
        #ytrain.append(fid)
        train_exp = tq.ExpectationValue(qc,H=tq.paulis.Z(0))
        ytrain.append(tq.simulate(train_exp,variables=test.angles))

    plt.plot(xdata, ytrain, 'o', color=col[k])
plt.show()

# %%
def qcircuit(xval, param):
    """
    Arg:
        - xval (array[tuple]): data point
        - param (dict): parameters dictionary
    Returns:
        - qc: quantum circuit
    """
    layers = int((len(param))/4) # 2 parameters/layer
    # initialize the circuit 
    qc = tq.gates.Rz(0.0,0)
    for p in range(0,4*layers-1,4):
        # add layers to the circuit
        qc += tq.gates.Rz(param[p]+param[p+1],0) + tq.gates.Ry(param[p+2],0)
        qc += tq.gates.Rz(param[p]-param[p+1]+param[p+3]*xval,0)
        #tq.gates.Ry(xval*param[p]+param[p+1],0) + tq.gates.Rz(xval*param[p+2]+param[p+3],0) 
    return qc

# %%
# Optimize
training_set = 50
layersmax = 6

# generate the training data
xdata=[]
ytrue=[]
for i in range(training_set):
    rand = random.uniform(-1,1)
    xdata.append(rand)
    ytrue.append(f(rand))    

plt.plot(xdata, ytrue, 'o', color='black')
    
zero=tq.QubitWaveFunction.from_array(np.asarray([1,0]))
zero=zero.normalize()
    
grad = '2-point' # numerical gradient (= None: analytical gradient)
mthd = 'BFGS' # scipy minimization method
mthd_opt = {'eps':1.e-4} # method options (that's the stepsize for the gradients)

col = ['red','blue','yellow','green','pink','brown']
 
for k in range(layersmax):
    layers = k+1
    # generate the variational parameters
    param = [tq.Variable(name='th_{}'.format(i)) for i in range(0,4*layers)]
    inval = {key : random.uniform(0, 2*np.pi) for key in param}

    #print(xdata)
    loss=0
    for i in range(training_set):
        wfn_targ = tq.QubitWaveFunction.from_array(np.asarray([np.sqrt((1+f(xdata[i]))/2),np.sqrt((1-f(xdata[i]))/2)]))
        wfn = wfn_targ.normalize()
        rho_targ =  tq.paulis.Projector(wfn=wfn)
        obj = tq.Objective.ExpectationValue(U=qcircuit(xdata[i], param), H=rho_targ)
        loss += (obj-f(xdata[i]))**2
    test = tq.minimize(objective=loss/len(xdata), initial_values=inval, method = mthd, gradient = grad, method_options = mthd_opt, silent=True)
    ytrain=[]
    for i in range(training_set):
        qc=qcircuit(xdata[i],param)
        #train_wfn = tq.simulate(qc,variables=test.angles)
        #fid = abs(train_wfn.inner(zero))**2
        #ytrain.append(fid)
        train_exp = tq.ExpectationValue(qc,H=tq.paulis.Z(0))
        ytrain.append(tq.simulate(train_exp,variables=test.angles))

    plt.plot(xdata, ytrain, 'o', color=col[k])
plt.show()
